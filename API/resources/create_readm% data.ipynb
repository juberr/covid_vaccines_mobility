# %%
import pandas as pd
columns = ['race', 'gender', 'age', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'a1cresult', 'diabetesmed', 'readmitted', 'num_meds_changed', 'total_hosp_visits']
df = pd.read_json('df_json.json')

# %%
df.columns = columns

# %%
df
# Out:
#                   race  gender  age admission_type_id  \
# 0            Caucasian       0    8         Emergency
# 1            Caucasian       0    9          Elective
# 2      AfricanAmerican       1    6         Emergency
# 3            Caucasian       0    5         Emergency
# 4      AfricanAmerican       1    7         Emergency
# ...                ...     ...  ...               ...
# 58875            Other       0    3         Emergency
# 58876            Other       1    7         Emergency
# 58877         Hispanic       1    3          Elective
# 58878        Caucasian       1    5         Emergency
# 58879            Other       1    4         Emergency
#
#       discharge_disposition_id admission_source_id  time_in_hospital  \
# 0           Discharged to Home               Other                13
# 1                        Other               Other                12
# 2                        Other      Emergency Room                12
# ...

# %%
group_df = df.groupby(['diag_1']).sum()

# %%
count_df = df.groupby(['diag_1']).count()

# %%
group_df['count'] = count_df['gender']

group_df['readm%'] = group_df['readmitted']/group_df['count']

# %%
final_df = group_df

# %%
final_df.to_json('highestreadm.js', orient='values')

# %%
final_df
# Out:
#         gender     age  time_in_hospital  num_lab_procedures  num_procedures  \
# diag_1
# 1          709    9760              8350               80551            1342
# 2         1027   13877             11576               86697            4926
# 3         2888   31765             25047              266562            5286
# 4          214    3812              2364               27151             882
# 5          574    6576              7583               53292             513
# 6          314    4619              3365               32445             519
# 7         9674  118290             77647              818749           39530
# 8         2556   37436             29195              272281            3658
# 9         2599   34397             24562              257619            8343
# 10        1264   19780             12868              146587            3296
# 11           0    1221              1550               15230             813
# ...
